# %% [markdown]
# **Email : asad713637@gmail.com**

# %%
# You must run this code and use that data set for all the questions
import numpy as np
import pandas as pd

np.random.seed(42)

ids = np.arange(1, 11)
ages = np.random.randint(18, 60, 10)
salaries = np.random.randint(30000, 90000, 10)
departments = np.array(["HR", "IT", "Finance", "IT", "HR", "Sales", "Finance", "IT", "Sales", "HR"])

DF = pd.DataFrame({
"id": ids,
"age": ages,
"salary": salaries,
"dept": departments
})

DF.to_csv("employees.csv", index=False)
print("Sample Data Created and Saved as employees.csv")
# Out:
# Sample Data Created and Saved as employees.csv

# %% [markdown]
# ## Ans to the question no - 1

# %%
print("Ages :",ages)
print("Salaries :",salaries)

#for ages
print(ages.dtype)
print(ages.ndim)
print(ages.shape)
print(ages.size)

#for salaries
print(salaries.dtype)
print(salaries.ndim)
print(salaries.shape)
print(salaries.size)
# Out:
# Ages : [56 46 32 25 38 56 36 40 28 28]
# Salaries : [77191 74131 46023 71090 31685 30769 89735 86101 32433 35311]
# int64
# 1
# (10,)
# 10
# int64
# 1
# (10,)
# 10

# %% [markdown]
# ## Ans to the question no -2

# %%
print("Ages :",ages)
print("Salaries :",salaries)

highest_salaries = np.max(salaries)
print("Highest Salaries :",highest_salaries)

lowest_salaries = np.min(salaries)
print("Lowest Salaries :",lowest_salaries)

average_salaries = np.mean(salaries)
print("Average Salaries :",average_salaries)

average_ages = np.mean(ages)
print("Average Ages :",average_ages)
# Out:
# Ages : [56 46 32 25 38 56 36 40 28 28]
# Salaries : [77191 74131 46023 71090 31685 30769 89735 86101 32433 35311]
# Highest Salaries : 89735
# Lowest Salaries : 30769
# Average Salaries : 57446.9
# Average Ages : 38.5

# %% [markdown]
# ## Ans to the question no -3

# %%
print("Ages :",ages)

ages_greater_than_30 = ages[ages > 30]
print("Ages greater than 30 :",ages_greater_than_30)

count = np.sum(ages > 30)
print("Count of ages greater than 30 :",count)
# Out:
# Ages : [56 46 32 25 38 56 36 40 28 28]
# Ages greater than 30 : [56 46 32 38 56 36 40]
# Count of ages greater than 30 : 7

# %% [markdown]
# ## Ans to the question no - 4

# %%
print("Ages :",ages)

updated_ages = ages + 5
print("Updated Ages :",updated_ages)
# Out:
# Ages : [56 46 32 25 38 56 36 40 28 28]
# Updated Ages : [61 51 37 30 43 61 41 45 33 33]

# %% [markdown]
# ## Ans to the question no -5

# %%
print("Salaries :",salaries)

total_salary = np.sum(salaries)
print("Total Salary :",total_salary)

maximum_salary = np.max(salaries)
print("Maximum Salary :",maximum_salary)

minimum_salary = np.min(salaries)
print("Minimum Salary :",minimum_salary)

difference_salary = maximum_salary - minimum_salary
print("Difference Salary :",difference_salary)
# Out:
# Salaries : [77191 74131 46023 71090 31685 30769 89735 86101 32433 35311]
# Total Salary : 574469
# Maximum Salary : 89735
# Minimum Salary : 30769
# Difference Salary : 58966

# %% [markdown]
# ## Ans to the question no -6

# %%
df = pd.read_csv("employees.csv")
print(df.head(5))
df.info()
df.describe()
# Out:
#    id  age  salary     dept
# 0   1   56   77191       HR
# 1   2   46   74131       IT
# 2   3   32   46023  Finance
# 3   4   25   71090       IT
# 4   5   38   31685       HR
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      10 non-null     int64
#  1   age     10 non-null     int64
#  2   salary  10 non-null     int64
#  3   dept    10 non-null     object
# dtypes: int64(3), object(1)
# memory usage: 452.0+ bytes
#              id       age        salary
# count  10.00000  10.00000     10.000000
# mean    5.50000  38.50000  57446.900000
# std     3.02765  11.16791  24357.262884
# min     1.00000  25.00000  30769.000000
# 25%     3.25000  29.00000  33152.500000
# 50%     5.50000  37.00000  58556.500000
# 75%     7.75000  44.50000  76426.000000
# max    10.00000  56.00000  89735.000000

# %% [markdown]
# ## Ans to the question no -7

# %%
df_columns = df.loc[:,['id','age','salary']]
df_columns.tail(3)
# Out:
#    id  age  salary
# 7   8   40   86101
# 8   9   28   32433
# 9  10   28   35311

# %% [markdown]
# ## Ans to the question no -8

# %%
it_dept = df.loc[df['dept'] == 'IT']
print(it_dept)

total_it_dept = len(it_dept)
print("Total IT Department Employees :",total_it_dept)
# Out:
#    id  age  salary dept
# 1   2   46   74131   IT
# 3   4   25   71090   IT
# 7   8   40   86101   IT
# Total IT Department Employees : 3

# %% [markdown]
# ## Ans to the question no - 9

# %%
sorted_salary = df.sort_values(by='salary',ascending=False)
sorted_salary.head(3)
# Out:
#    id  age  salary     dept
# 6   7   36   89735  Finance
# 7   8   40   86101       IT
# 0   1   56   77191       HR

# %% [markdown]
# ## Ans to the question no - 10

# %%
df.loc[df['salary'] > 80000, 'salary'] = 80000
print(df)

average_salary =df['salary'].mean()
print("Average Salary :",average_salary)
# Out:
#    id  age  salary     dept
# 0   1   56   77191       HR
# 1   2   46   74131       IT
# 2   3   32   46023  Finance
# 3   4   25   71090       IT
# 4   5   38   31685       HR
# 5   6   56   30769    Sales
# 6   7   36   80000  Finance
# 7   8   40   80000       IT
# 8   9   28   32433    Sales
# 9  10   28   35311       HR
# Average Salary : 55863.3
